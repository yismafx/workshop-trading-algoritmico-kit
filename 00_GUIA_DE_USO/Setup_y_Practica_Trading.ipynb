# %% [markdown]
# # 🚀 Setup Workshop: Trading Algorítmico Aumentado con IA Generativa
#
# **Versión:** 3.5 Corregida (Noviembre 2025)
# **Instructor:** Yismary Quintero (@yismafx)
# **Duración:** 5-10 minutos
#
# ---
#
# ## 🎯 ¿Qué es Este Notebook?
#
# Este notebook contiene **código ya funcionando** para preparar tu entorno de trabajo.
#
# ### ⚠️ IMPORTANTE: NO Vas a Programar
#
# - ✅ Todo el código **ya está escrito**
# - ✅ Solo **ejecutas** cada celda
# - ✅ El código **instala herramientas** automáticamente
# - ✅ Tú **validas** que funcione
#
# **En el workshop:**
# - Usarás herramientas ya funcionando
# - IA te ayudará a ADAPTAR (no crear desde cero)
# - Serás USUARIO AVANZADO de sistemas
#
# ---
#
# ## 📋 Contenido de este Notebook
#
# 1. ✅ Instalación automática de herramientas
# 2. ✅ Validación del setup
# 3. ✅ Configuración de broker (Alpaca)
# 4. ✅ Test final
#
# **Todo pre-escrito. Tú solo ejecutas.** 👇
#
# ---
#
# ## 🎯 Instrucciones de Uso
#
# **Ejecuta las celdas EN ORDEN, una por una.**
#
# **Cómo ejecutar:**
# 1. Click en la celda de código
# 2. Presiona **Shift + Enter**
# 3. Espera a que termine
# 4. Continúa con la siguiente
#
# **Símbolos:**
# - 🔵 **Celda Información** = Solo leer
# - ⚙️ **Celda Código** = EJECUTAR con Shift+Enter
# - ⚠️ **Acción Manual** = Tú haces algo (te diremos qué)
#
# ---
#
# ## ⏱️ Tiempo Estimado
#
# - Instalación: 2-3 minutos
# - Restart: 30 segundos
# - Validación: 10 segundos
# - Configuración Alpaca: 5 minutos
# - **Total: ~10 minutos**
#
# ---
#
# ¡Comencemos! 👇

# %% [markdown]
# ---
#
# # 📝 PASO 1: Nombrar Este Notebook
#
# ## ⚠️ ACCIÓN MANUAL REQUERIDA
#
# **ANTES de ejecutar código, nombra este notebook:**
#
# 1. Click arriba donde dice el nombre del archivo
# 2. Cámbialo a: `Setup_Workshop_Trading`
# 3. Presiona Enter
#
# **¿Por qué?**
# Para identificar este notebook después.
#
# **Analogía:**
# Como nombrar un proyecto en TradingView antes de empezar.
#
# ---
#
# ✅ **Cuando esté nombrado, continúa al Paso 2** ⬇️

# %% [markdown]
# ---
#
# # 📦 PASO 2: Instalación Automática de Herramientas
#
# ## ⚙️ CÓDIGO PRE-ESCRITO - SOLO EJECUTAR
#
# **Lo que hará este código (automáticamente):**
# - Instalará herramientas para descargar datos de mercados
# - Instalará herramientas para backtesting
# - Instalará herramientas para conectar con brokers
# - Instalará herramientas para análisis técnico
#
# **Tú NO escribes nada. Solo ejecutas.**
#
# **Instrucciones:**
# 1. Click en la celda de abajo
# 2. Presiona **Shift + Enter**
# 3. Espera 2-3 minutos
# 4. Ignora advertencias en texto naranja (normales)
#
# ---
#
# 👇 **EJECUTA AHORA** (Shift+Enter)

# %%
# ═══════════════════════════════════════════════════════════
# 📦 INSTALACIÓN AUTOMÁTICA v3.5 CORREGIDA
# Workshop: Trading Algorítmico Aumentado con IA Generativa
# ═══════════════════════════════════════════════════════════
# 
# ⚠️ IMPORTANTE: Este código YA ESTÁ ESCRITO
# Tú NO necesitas entender cada línea
# Solo ejecuta y espera
#
# ═══════════════════════════════════════════════════════════

print("🚀 Instalando herramientas de trading automáticamente...")
print("   No necesitas hacer nada más que esperar.\n")
print("⏱️  Tiempo estimado: 2-3 minutos\n")

print("═" * 60)
print("📥 INSTALANDO HERRAMIENTAS")
print("═" * 60)

# Herramienta 1: Descargar datos de mercados
print("\n📈 [1/6] Instalando yfinance (datos de mercados)...")
# !pip install -q yfinance
print("   ✅ yfinance instalado")

# Herramienta 2: Conectar con broker
print("\n📊 [2/6] Instalando alpaca-py (broker paper trading)...")
# !pip install -q alpaca-py
print("   ✅ alpaca-py instalado")

# Herramienta 3: Backtesting
print("\n🧪 [3/6] Instalando vectorbt (backtesting)...")
# !pip install -q vectorbt
print("   ✅ vectorbt instalado")

# Herramienta 4: Análisis técnico
print("\n📉 [4/6] Instalando ta (indicadores técnicos)...")
# !pip install -q ta
print("   ✅ ta instalado")

# Herramienta 5: Indicadores adicionales (opcional)
print("\n📊 [5/6] Instalando pandas-ta (más indicadores)...")
try:
    # !pip install -q pandas-ta --no-deps
    print("   ✅ pandas-ta instalado")
except:
    print("   ⚠️  pandas-ta opcional - no disponible (no es problema)")

# Herramienta 6: Gráficos
print("\n🎨 [6/6] Instalando plotly (gráficos)...")
# !pip install -q plotly
print("   ✅ plotly instalado")

print("\n" + "═" * 60)
print("🎉 ¡INSTALACIÓN COMPLETADA!")
print("═" * 60)

print("\n✅ Herramientas instaladas:")
print("   • yfinance (descarga datos)")
print("   • alpaca-py (broker)")
print("   • vectorbt (backtesting)")
print("   • ta (análisis técnico)")
print("   • plotly (gráficos)")

print("\n" + "🔴" * 20)
print("⚠️  PASO OBLIGATORIO AHORA")
print("🔴" * 20)

print("\n🔄 DEBES REINICIAR LA SESIÓN:")
print("   1. Ve al menú: Runtime → Restart session")
print("   2. Click 'Yes'")
print("   3. Espera 10 segundos")
print("   4. NO ejecutes nada más hasta reiniciar")

print("\n💡 ¿Por qué?")
print("   Python necesita 'recargar' las nuevas herramientas.")
print("   Es como reiniciar TradingView después de instalar indicadores.")

print("\n⚠️  NO continúes sin antes hacer: Runtime → Restart session")
print("\n" + "═" * 60)

# %% [markdown]
# ---
#
# # 🔄 PASO 3: Reiniciar Sesión
#
# ## ⚠️ ACCIÓN MANUAL OBLIGATORIA
#
# **DETENTE AQUÍ y haz lo siguiente:**
#
# ### Instrucciones:
#
# 1. **Ve al menú superior** → Click en **Runtime**
# 2. **Click en: Restart session**
# 3. Ventana de confirmación → **Click "Yes"**
# 4. **Espera 10 segundos**
# 5. Las salidas de celdas desaparecerán (normal)
#
# ---
#
# ### 💡 ¿Qué es "reiniciar sesión"?
#
# **Analogía simple:**
# - Sesión = La "memoria activa" de Python
# - Reiniciar = "Refrescar" para que reconozca herramientas nuevas
# - Tu notebook NO se pierde (está guardado)
#
# Es como:
# - Cerrar y abrir TradingView después de instalar indicadores
# - Reiniciar MetaTrader después de agregar EAs
#
# ---
#
# ### ✅ ¿Cómo sé que reinició?
#
# - Verás "Conectado" arriba a la derecha
# - Las salidas de celdas anteriores desaparecieron
# - Puedes ejecutar celdas nuevamente
#
# ---
#
# ✅ **Cuando hayas reiniciado, continúa al Paso 4** ⬇️

# %% [markdown]
# ---
#
# # ✅ PASO 4: Validación Automática
#
# ## ⚙️ CÓDIGO PRE-ESCRITO - SOLO EJECUTAR
#
# **Lo que hará este código (automáticamente):**
# - Verificará que todas las herramientas funcionan
# - Te mostrará una lista con ✅ o ❌
# - Si todo sale ✅ → Estás listo
#
# **Tú NO escribes nada. Solo ejecutas.**
#
# **Instrucciones:**
# 1. ✅ Asegúrate de haber reiniciado (Paso 3)
# 2. Click en la celda de abajo
# 3. Presiona **Shift + Enter**
# 4. Espera ~10 segundos
#
# **Resultado esperado:**
# - ✅ Todas las herramientas marcadas como "Funcionando"
# - 🎉 Mensaje: "¡TODAS LAS HERRAMIENTAS VALIDADAS!"
#
# ---
#
# 👇 **EJECUTA AHORA** (después de restart)

# %%
# ═══════════════════════════════════════════════════════════
# ✅ VALIDACIÓN AUTOMÁTICA v3.5 CORREGIDA
# ═══════════════════════════════════════════════════════════
# 
# ⚠️ Este código verifica automáticamente que todo funcione
# Tú solo observas los resultados
#
# ═══════════════════════════════════════════════════════════

import sys

print("🔍 VALIDANDO HERRAMIENTAS AUTOMÁTICAMENTE...\n")
print("═" * 60)

# Lista de herramientas a validar
herramientas = [
    ("pandas", "import pandas as pd"),
    ("numpy", "import numpy as np"),
    ("matplotlib", "import matplotlib.pyplot as plt"),
    ("yfinance", "import yfinance as yf"),
    ("alpaca-py", "from alpaca.trading.client import TradingClient"),
    ("vectorbt", "import vectorbt as vbt"),
    ("ta", "from ta.trend import SMAIndicator"),
    ("plotly", "import plotly.graph_objects as go"),
]

errores = []
exitosos = []

# Validar cada herramienta
for nombre, test in herramientas:
    try:
        exec(test)
        print(f"✅ {nombre:<20} Funcionando correctamente")
        exitosos.append(nombre)
    except Exception as e:
        print(f"❌ {nombre:<20} ERROR")
        errores.append(nombre)

print("═" * 60)

# Reporte
if not errores:
    print("\n🎉 ¡TODAS LAS HERRAMIENTAS VALIDADAS!")
    print(f"✅ {len(exitosos)}/{len(herramientas)} herramientas funcionan")
    print("\n📍 Estás 100% listo para el workshop")
    print("\n🎯 Próximo paso: Configurar broker Alpaca (Paso 5)")
else:
    print(f"\n❌ ERROR: {len(errores)} herramienta(s) NO funcionan")
    print("\n🔧 Solución:")
    print("   1. Verifica que ejecutaste Runtime → Restart session")
    print("   2. Re-ejecuta el Paso 2 (instalación)")
    print("   3. Vuelve a reiniciar")
    print("   4. Ejecuta esta validación nuevamente")

print("\n" + "═" * 60)
print(f"📍 Python: {sys.version.split()[0]}")
print(f"📍 Entorno: Google Colab")
print("═" * 60)

# %% [markdown]
# ---
#
# # 🔑 PASO 5: Diagnóstico Completo - Conexión Alpaca
#
# ## ⚠️ PREREQUISITO: Cuenta Alpaca
#
# **Necesitas crear cuenta PAPER en Alpaca (gratis, 5 min):**
#
# ### Instrucciones:
#
# #### A. Crear Cuenta (5 min)
# 1. Ve a: https://app.alpaca.markets/signup
# 2. Click: "**Paper Trading Only**" (NO real trading)
# 3. Completa registro básico
# 4. Verifica email
# 5. Login
#
# #### B. Obtener Llaves API (2 min)
# 1. En Alpaca → Click tu nombre (arriba derecha)
# 2. **View API Keys**
# 3. Copia **ambas llaves COMPLETAS**:
#    - API Key ID (empieza con "PK")
#    - Secret Key (cadena larga)
#
# ---
#
# ### ⚙️ Configurar en el Código
#
# **En la celda de abajo:**
# 1. Reemplaza `"TU_API_KEY_AQUI"` con tu API Key real
# 2. Reemplaza `"TU_SECRET_KEY_AQUI"` con tu Secret Key real
# 3. **IMPORTANTE:** Asegúrate de copiar las llaves COMPLETAS (sin espacios extra)
# 4. Ejecuta la celda
#
# **Ejemplo:**
# ```python
# # ANTES:
# API_KEY = "TU_API_KEY_AQUI"
#
# # DESPUÉS:
# API_KEY = "PKA1B2C3D4E5F6G7H8I9J0"
# ```
#
# ---
#
# 👇 **PEGA TUS LLAVES Y EJECUTA**

# %%
# ═══════════════════════════════════════════════════════════
# 🔍 DIAGNÓSTICO COMPLETO - CONEXIÓN ALPACA v3.5 CORREGIDA
# ═══════════════════════════════════════════════════════════

# ⚠️ PEGA TUS LLAVES AQUÍ (las que acabas de generar)
API_KEY = "TU_API_KEY_AQUI"  # ← Pega aquí
SECRET_KEY = "TU_SECRET_KEY_AQUI"  # ← Pega aquí

print("🔍 DIAGNÓSTICO DE CONEXIÓN ALPACA")
print("=" * 60)

# ════════════════════════════════════════════════════════════
# 1. VERIFICAR FORMATO DE LLAVES
# ════════════════════════════════════════════════════════════
print("\n📋 1. Verificando formato de llaves...")

# Verificar API Key
if not API_KEY or API_KEY == "TU_API_KEY_AQUI":
    print("❌ API_KEY no configurado")
    print("   → Debes reemplazar 'TU_API_KEY_AQUI' con tu llave real")
else:
    print(f"✅ API_KEY configurado")
    print(f"   - Longitud: {len(API_KEY)} caracteres")
    print(f"   - Primeros 10: {API_KEY[:10]}...")
    print(f"   - Empieza con 'PK': {'✅' if API_KEY.startswith('PK') else '❌'}")

# Verificar Secret Key
if not SECRET_KEY or SECRET_KEY == "TU_SECRET_KEY_AQUI":
    print("❌ SECRET_KEY no configurado")
    print("   → Debes reemplazar 'TU_SECRET_KEY_AQUI' con tu llave real")
else:
    print(f"✅ SECRET_KEY configurado")
    print(f"   - Longitud: {len(SECRET_KEY)} caracteres")
    print(f"   - Primeros 10: {SECRET_KEY[:10]}...")

# ════════════════════════════════════════════════════════════
# 2. VERIFICAR QUE LLAVES NO TENGAN ESPACIOS
# ════════════════════════════════════════════════════════════
print("\n📋 2. Verificando espacios extra...")

if API_KEY != API_KEY.strip():
    print("⚠️  API_KEY tiene espacios al inicio o final")
    API_KEY = API_KEY.strip()
    print("   → Espacios eliminados automáticamente")
else:
    print("✅ API_KEY sin espacios extra")

if SECRET_KEY != SECRET_KEY.strip():
    print("⚠️  SECRET_KEY tiene espacios al inicio o final")
    SECRET_KEY = SECRET_KEY.strip()
    print("   → Espacios eliminados automáticamente")
else:
    print("✅ SECRET_KEY sin espacios extra")

# ════════════════════════════════════════════════════════════
# 3. INTENTAR CONEXIÓN
# ════════════════════════════════════════════════════════════
print("\n📋 3. Intentando conexión con Alpaca...")

if API_KEY == "TU_API_KEY_AQUI" or SECRET_KEY == "TU_SECRET_KEY_AQUI":
    print("\n" + "=" * 60)
    print("⛔ DETENTE: Necesitas configurar tus llaves primero")
    print("=" * 60)
    print("\n🔧 PASOS:")
    print("   1. Ve a: https://app.alpaca.markets/paper/dashboard/overview")
    print("   2. Click en tu nombre → 'Your API Keys'")
    print("   3. Copia tu API Key y Secret Key")
    print("   4. Reemplaza arriba en el código")
    print("   5. Ejecuta esta celda nuevamente")
else:
    try:
        from alpaca.trading.client import TradingClient
        
        print("   → Creando cliente...")
        trading_client = TradingClient(API_KEY, SECRET_KEY, paper=True)
        
        print("   → Solicitando información de cuenta...")
        account = trading_client.get_account()
        
        print("\n" + "=" * 60)
        print("🎉 ¡CONEXIÓN EXITOSA!")
        print("=" * 60)
        print("\n📊 TU CUENTA PAPER:")
        print("=" * 60)
        print(f"💰 Balance: ${float(account.cash):.2f}")
        print(f"📈 Poder de compra: ${float(account.buying_power):.2f}")
        print(f"📊 Valor portafolio: ${float(account.portfolio_value):.2f}")
        print(f"✅ Estado: {account.status}")
        print(f"🆔 Account ID: {account.id}")
        print("=" * 60)
        
        print("\n✅ ¡TODO FUNCIONA PERFECTAMENTE!")
        print("\n📍 Próximo paso: Continúa al Paso 6 (Descargar datos)")
        
    except Exception as e:
        error_msg = str(e)
        
        print("\n" + "=" * 60)
        print("❌ ERROR AL CONECTAR")
        print("=" * 60)
        
        print(f"\n🔴 Error completo:\n{error_msg}\n")
        
        print("🔧 DIAGNÓSTICO:")
        
        # Analizar tipo de error
        if "forbidden" in error_msg.lower() or "unauthorized" in error_msg.lower():
            print("\n❌ CREDENCIALES INVÁLIDAS")
            print("\n💡 Causas posibles:")
            print("   1. Las llaves son incorrectas")
            print("   2. Las llaves son de LIVE trading (no PAPER)")
            print("   3. Las llaves fueron revocadas")
            print("\n🔧 Solución:")
            print("   1. Ve a Alpaca Paper Dashboard")
            print("   2. ELIMINA las llaves actuales")
            print("   3. GENERA nuevas llaves")
            print("   4. Asegúrate de estar en modo PAPER")
            print("   5. Copia las nuevas llaves COMPLETAS")
            
        elif "invalid" in error_msg.lower() or "authentication" in error_msg.lower():
            print("\n❌ PROBLEMA DE AUTENTICACIÓN")
            print("\n💡 Causas posibles:")
            print("   1. API Key o Secret Key están incompletos")
            print("   2. Copiaste mal al pegar (faltan caracteres)")
            print("   3. Hay caracteres extra o espacios")
            print("\n🔧 Solución:")
            print("   1. Borra completamente las llaves del código")
            print("   2. Ve a Alpaca y copia nuevamente")
            print("   3. Pega con cuidado (Ctrl+V o Cmd+V)")
            print("   4. Verifica que NO haya espacios extra")
            
        elif "connection" in error_msg.lower() or "timeout" in error_msg.lower():
            print("\n❌ PROBLEMA DE CONEXIÓN")
            print("\n💡 Causas posibles:")
            print("   1. No hay conexión a internet")
            print("   2. Firewall bloqueando Alpaca")
            print("   3. Problema temporal de Alpaca")
            print("\n🔧 Solución:")
            print("   1. Verifica tu conexión a internet")
            print("   2. Intenta en 1 minuto")
            print("   3. Usa otra red si persiste")
            
        else:
            print("\n❌ ERROR DESCONOCIDO")
            print("\n🔧 Solución:")
            print("   1. Captura screenshot de este error")
            print("   2. Contacta al instructor")
            print("   3. Email: yismaryme@gmail.com")

print("\n" + "=" * 60)

# %% [markdown]
# ---
#
# # 📥 PASO 6: Descargar Datos Históricos de SPY (Alpaca)
#
# ## ⚙️ CÓDIGO PRE-ESCRITO - SOLO EJECUTAR
#
# **Lo que hará este código:**
# - Descargará datos históricos de SPY (últimos 5 años)
# - Validará restricciones del plan gratuito de Alpaca
# - **CORRECCIÓN IMPLEMENTADA:** Manejará correctamente el MultiIndex que devuelve Alpaca
# - Verificará la calidad de los datos
# - Mostrará estadísticas básicas
#
# **⚠️ IMPORTANTE:** Alpaca plan Basic tiene restricción de 15 minutos para datos históricos
#
# Según documentación oficial: https://docs.alpaca.markets/docs/about-market-data-api
# - **Plan Basic:** Retraso de 15 minutos para datos históricos
# - **Plan Algo Trader Plus ($99/mes):** Sin restricción
#
# El código ajusta automáticamente las fechas para evitar errores.
#
# ---
#
# 👇 **EJECUTA AHORA** (Shift+Enter)

# %%
# ═══════════════════════════════════════════════════════════
# 📥 DESCARGAR DATOS HISTÓRICOS DE SPY (ALPACA) v3.5 CORREGIDA
# Versión Profesional con Validación de Restricciones
# ═══════════════════════════════════════════════════════════
# 🎓 TEORÍA (López de Prado, 2018):
# "La calidad del backtesting depende de la calidad de los datos.
#  Validar fechas ANTES de solicitar datos evita errores silenciosos."
# ═══════════════════════════════════════════════════════════

from alpaca.data.historical import StockHistoricalDataClient
from alpaca.data.requests import StockBarsRequest
from alpaca.data.timeframe import TimeFrame
from datetime import datetime, timedelta
import pandas as pd

print("📥 Descargando datos de SPY...")
print("=" * 60)

# ════════════════════════════════════════════════════════════
# VALIDACIÓN 1: Fechas por defecto con restricción de Alpaca
# ════════════════════════════════════════════════════════════

# ⚠️ RESTRICCIÓN CRÍTICA DE ALPACA (Plan Basic)
# Según documentación oficial: https://docs.alpaca.markets/docs/about-market-data-api
# - Plan Basic: Retraso de 15 minutos para datos históricos
# - Plan Algo Trader Plus ($99/mes): Sin restricción

end_date = datetime.now() - timedelta(days=1)  # ✅ Usar AYER (más seguro)
start_date = end_date - timedelta(days=365*5)  # 5 años atrás desde ayer

print(f"📅 Fecha inicio: {start_date.date()} (5 años atrás)")
print(f"📅 Fecha fin: {end_date.date()} (ayer)")

# ════════════════════════════════════════════════════════════
# VALIDACIÓN 2: Verificar restricción de 15 minutos
# ════════════════════════════════════════════════════════════

ahora = datetime.now()
diferencia_minutos = (ahora - end_date).total_seconds() / 60

if diferencia_minutos < 15:
    print("\n⚠️ ADVERTENCIA: Restricción de plan gratuito detectada")
    print(f"   Intentas datos de hace {diferencia_minutos:.0f} minutos")
    print(f"   Plan gratuito requiere al menos 15 minutos de antigüedad")
    print(f"   Ajustando automáticamente a: {(ahora - timedelta(minutes=20)).date()}")
    end_date = ahora - timedelta(minutes=20)  # 20 min para estar seguros

print("=" * 60)

# ════════════════════════════════════════════════════════════
# DESCARGA CON MANEJO DE ERRORES
# ════════════════════════════════════════════════════════════

try:
    # Crear cliente
    data_client = StockHistoricalDataClient(API_KEY, SECRET_KEY)
    
    # Crear request
    request_params = StockBarsRequest(
        symbol_or_symbols=["SPY"],
        timeframe=TimeFrame.Day,
        start=start_date,
        end=end_date
    )
    
    # Ejecutar descarga
    print(f"\n🔄 Solicitando datos a Alpaca...")
    bars = data_client.get_stock_bars(request_params)
    
    # Convertir a DataFrame
    df = bars.df
    
    # ════════════════════════════════════════════════════════════
    # CORRECCIÓN: Manejar MultiIndex de Alpaca
    # ════════════════════════════════════════════════════════════
    
    # Alpaca devuelve MultiIndex (symbol, timestamp)
    # Necesitamos acceder solo al nivel de timestamp
    if isinstance(df.index, pd.MultiIndex):
        # Eliminar el nivel de símbolo, quedarnos solo con timestamp
        df.index = df.index.droplevel(0)
        print("\n✅ MultiIndex corregido - usando solo timestamp")
    
    # ════════════════════════════════════════════════════════════
    # VALIDACIÓN 3: Verificar calidad de datos
    # ════════════════════════════════════════════════════════════
    
    if df.empty:
        raise ValueError(
            f"❌ No se encontraron datos para SPY en el período especificado"
        )
    
    # Verificar valores nulos
    nulos_por_columna = df.isnull().sum()
    if nulos_por_columna.any():
        print(f"\n⚠️ Advertencia: Datos con valores nulos detectados:")
        print(nulos_por_columna[nulos_por_columna > 0])
    
    # ════════════════════════════════════════════════════════════
    # RESUMEN DE DESCARGA
    # ════════════════════════════════════════════════════════════
    
    print(f"\n✅ Descarga completada exitosamente")
    print("=" * 60)
    print(f"📊 Símbolo: SPY")
    print(f"📅 Período: {df.index[0].date()} a {df.index[-1].date()}")
    print(f"📈 Total de registros: {len(df)}")
    print(f"💰 Precio más reciente: ${df['close'].iloc[-1]:.2f}")
    print(f"💰 Precio más antiguo: ${df['close'].iloc[0]:.2f}")
    print(f"📈 Retorno total: {((df['close'].iloc[-1] / df['close'].iloc[0]) - 1) * 100:.2f}%")
    print("=" * 60)
    
    # Mostrar primeras y últimas filas
    print("\n📋 Primeras 3 filas:")
    print(df.head(3))
    
    print("\n📋 Últimas 3 filas (más recientes):")
    print(df.tail(3))
    
    print("\n🎉 ¡Datos descargados exitosamente!")
    print("\n📍 Próximo paso: Validación final completa (Paso 7)")
    
except Exception as e:
    error_msg = str(e)
    
    # ════════════════════════════════════════════════════════════
    # DIAGNÓSTICO DE ERRORES COMUNES
    # ════════════════════════════════════════════════════════════
    
    if "subscription does not permit" in error_msg.lower():
        print(f"\n❌ ERROR: Restricción de suscripción gratuita")
        print(f"   Causa: Intentaste acceder a datos muy recientes (<15 min)")
        print(f"\n🔧 Solución:")
        print(f"   1. El código ya ajustó end_date a 1 día atrás")
        print(f"   2. Si persiste, espera 5 minutos y ejecuta nuevamente")
        print(f"   3. O considera actualizar a Algo Trader Plus ($99/mes)")
    
    elif "invalid credentials" in error_msg.lower():
        print(f"\n❌ ERROR: Credenciales inválidas")
        print(f"   Verifica que API_KEY y SECRET_KEY sean correctos")
        print(f"   Vuelve al Paso 5 para verificar tus credenciales")
    
    elif "connection" in error_msg.lower() or "timeout" in error_msg.lower():
        print(f"\n❌ ERROR: Problema de conexión")
        print(f"   Verifica tu conexión a internet")
        print(f"   Intenta ejecutar la celda nuevamente en 30 segundos")
    
    else:
        print(f"\n❌ ERROR DESCONOCIDO:")
        print(f"   {error_msg}")
        print(f"\n📞 Contacta al instructor si persiste")
    
    raise  # Re-lanzar el error para debugging

# %% [markdown]
# ---
#
# # 🔍 PASO 7: Validación Final Completa
#
# ## ⚙️ CÓDIGO PRE-ESCRITO - SOLO EJECUTAR
#
# **Lo que hará este código (automáticamente):**
# - Verificará que todas las herramientas estén instaladas
# - Validará la conexión con Alpaca
# - Confirmará que los datos se descargaron correctamente
# - Generará un reporte completo del estado del setup
#
# **Este es el paso final. Si todo está ✅ OK, estarás 100% listo para el workshop.**
#
# ---
#
# 👇 **EJECUTA AHORA** (Shift+Enter)

# %%
# ═══════════════════════════════════════════════════════════
# 🔍 VALIDACIÓN COMPLETA DEL SETUP v3.5
# ═══════════════════════════════════════════════════════════
# Este script verifica que todo esté funcionando correctamente
# ═══════════════════════════════════════════════════════════

import sys

print("🔍 VALIDACIÓN COMPLETA DEL SETUP")
print("=" * 60)

validation_results = []

# ════════════════════════════════════════════════════════════
# 1. Verificar Librerías
# ════════════════════════════════════════════════════════════
print("\n📦 Verificando librerías instaladas...")

required_libraries = [
    "pandas",
    "numpy",
    "matplotlib",
    "yfinance",
    "alpaca",
    "vectorbt",
    "ta",
    "plotly"
]

for lib in required_libraries:
    try:
        __import__(lib)
        validation_results.append((lib.capitalize(), "✅ OK"))
    except ImportError:
        validation_results.append((lib.capitalize(), "❌ NO INSTALADA"))

# ════════════════════════════════════════════════════════════
# 2. Verificar Configuración de Alpaca
# ════════════════════════════════════════════════════════════
print("\n🔑 Verificando configuración de Alpaca...")

try:
    if 'API_KEY' in globals() and API_KEY != "TU_API_KEY_AQUI":
        from alpaca.trading.client import TradingClient
        test_client = TradingClient(API_KEY, SECRET_KEY, paper=True)
        account = test_client.get_account()
        validation_results.append(("Alpaca Configurado", "✅ OK"))
        validation_results.append((f"Balance: ${float(account.cash):.2f}", "✅ OK"))
    else:
        validation_results.append(("Alpaca Configurado", "❌ NO CONFIGURADO"))
except Exception as e:
    validation_results.append(("Alpaca Configurado", f"❌ ERROR: {str(e)[:30]}"))

# ════════════════════════════════════════════════════════════
# 3. Verificar Datos Descargados
# ════════════════════════════════════════════════════════════
print("\n🌐 Verificando datos descargados...")

try:
    if 'df' in globals() and len(df) > 0:
        validation_results.append(("Datos Históricos", "✅ OK"))
        validation_results.append((f"Total de Registros: {len(df)}", "✅ OK"))
        
        # Validar calidad de datos
        dias_unicos = len(df.index.unique())
        if dias_unicos > 1000:  # Al menos ~4 años de datos
            validation_results.append(("Calidad de Datos", "✅ EXCELENTE"))
        elif dias_unicos > 250:  # Al menos 1 año
            validation_results.append(("Calidad de Datos", "✅ BUENA"))
        else:
            validation_results.append(("Calidad de Datos", "⚠️ INSUFICIENTE"))
    else:
        validation_results.append(("Datos Históricos", "❌ NO DESCARGADOS"))
except:
    validation_results.append(("Datos Históricos", "❌ ERROR"))

# ════════════════════════════════════════════════════════════
# 4. Imprimir Resultados
# ════════════════════════════════════════════════════════════
print("\n" + "=" * 60)
print("📊 RESULTADOS DE LA VALIDACIÓN")
print("=" * 60)

for item, status in validation_results:
    print(f"{item:.<40} {status}")

# ════════════════════════════════════════════════════════════
# 5. Veredicto Final
# ════════════════════════════════════════════════════════════
print("\n" + "=" * 60)

failed = [item for item, status in validation_results if "❌" in status]
warnings = [item for item, status in validation_results if "⚠️" in status]

if len(failed) == 0 and len(warnings) == 0:
    print("🎉 ¡TODO PERFECTO! SETUP COMPLETADO AL 100%")
    print("=" * 60)
    print("\n✅ Estás listo para empezar el workshop")
    print("✅ Todas las herramientas están funcionando")
    print("✅ Tu conexión a Alpaca está activa")
    print("✅ Puedes descargar y analizar datos")
    print("\n🎓 Próximos pasos:")
    print("   1. Guarda este notebook (ya se guardó automáticamente)")
    print("   2. Revisa la documentación del workshop")
    print("   3. Únete al grupo de Telegram")
    print("   4. Espera el inicio de la Sesión 1")
elif len(failed) == 0 and len(warnings) > 0:
    print("✅ SETUP FUNCIONAL (con advertencias menores)")
    print("=" * 60)
    print(f"\n⚠️  Advertencias ({len(warnings)}):")
    for item in warnings:
        print(f"   - {item}")
    print("\n💡 Las advertencias no bloquean el workshop")
    print("   Puedes continuar normalmente")
else:
    print("⚠️  HAY PROBLEMAS EN EL SETUP")
    print("=" * 60)
    print(f"\n❌ Componentes con error ({len(failed)}):")
    for item in failed:
        print(f"   - {item}")
    print("\n💡 Solución:")
    print("   - Revisa los pasos anteriores que fallaron")
    print("   - Vuelve a ejecutar esos pasos")
    print("   - Contacta soporte si persiste el problema")

print("\n" + "=" * 60)
print(f"📍 Python: {sys.version.split()[0]}")
print(f"📍 Entorno: Google Colab")
print(f"📍 Versión Notebook: 3.5 (Corregida Nov 2025)")
print("=" * 60)

# %% [markdown]
# ---
#
# # 🎉 ¡SETUP COMPLETADO!
#
# ## ✅ Checklist Final
#
# Si llegaste aquí y todo funcionó:
#
# - ✅ Notebook nombrado
# - ✅ Herramientas instaladas (8/8)
# - ✅ Sesión reiniciada
# - ✅ Validación exitosa
# - ✅ Cuenta Alpaca configurada
# - ✅ Conexión exitosa con broker
# - ✅ Datos de SPY descargados (con MultiIndex corregido)
# - ✅ Validación final completa
#
# **¡Felicidades! Estás 100% listo para el workshop.** 🎊
#
# ---
#
# ## 🎯 Lo Que Lograste
#
# **Instalaste herramientas ya funcionando para:**
# - ✅ Descargar datos de mercados
# - ✅ Hacer backtesting de estrategias
# - ✅ Conectar con broker (paper trading)
# - ✅ Analizar indicadores técnicos
# - ✅ Visualizar resultados
#
# **En el workshop:**
# - Usarás ESTAS herramientas (ya instaladas)
# - IA te ayudará a ADAPTAR código a tus estrategias
# - NO programarás desde cero
# - Serás USUARIO AVANZADO de sistemas
#
# ---
#
# ## 🚀 Próximos Pasos
#
# **ANTES de la Sesión 1:**
# 1. ✅ Guarda este notebook (File → Save)
# 2. ✅ Descarga copia (File → Download .ipynb)
# 3. ✅ Confirma en el grupo que completaste setup
#
# **Durante el Workshop:**
# - Usarás este notebook como base
# - Agregarás nuevas celdas con código pre-hecho
# - IA te ayudará a adaptar a tus estrategias
#
# ---
#
# ## 💡 Recordatorio Importante
#
# ### ⚠️ Sobre Colab:
#
# **Sesión vs Notebook:**
# - **Sesión** = Memoria temporal (se borra al cerrar)
# - **Notebook** = Tu código (se guarda automáticamente)
#
# **Si cierras y vuelves:**
# 1. Tu código está guardado ✅
# 2. Pero sesión se reinició ⚠️
# 3. Re-ejecuta instalación (Paso 2) si necesario
#
# ---
#
# ## 🆘 Soporte
#
# **Si tienes problemas:**
# - 💬 Grupo Telegram del workshop
# - 📧 Email instructor: yismaryme@gmail.com
# - 📄 Documento troubleshooting
#
# ---
#
# ## 🔧 Correcciones Implementadas en v3.5
#
# **Paso 5 (Diagnóstico Conexión Alpaca):**
# - ✅ Validación mejorada de formato de llaves API y Secret
# - ✅ Detección automática de espacios extra
# - ✅ Diagnóstico específico por tipo de error
# - ✅ Mensajes de error más claros y accionables
#
# **Paso 6 (Descarga de Datos):**
# - ✅ **CORRECCIÓN CRÍTICA:** Manejo del MultiIndex de Alpaca
# - ✅ Validación de restricción de 15 minutos (plan gratuito)
# - ✅ Manejo robusto de errores comunes
# - ✅ Diagnóstico mejorado de problemas de conexión
#
# ---
#
# # 🎊 ¡Nos Vemos en la Sesión 1!
#
# **Estás preparado para comenzar tu viaje en:**
#
# **Trading Algorítmico Aumentado con IA Generativa**
#
# - ✅ Herramientas instaladas
# - ✅ Broker configurado
# - ✅ Datos descargados (formato corregido)
# - ✅ Listo para USAR sistemas
# - ✅ IA como tu COPILOTO
#
# **Yismary Quintero (@yismafx)**
# Instructora - Workshop Trading Algorítmico
#
# ---
#
# *Versión 3.5 Corregida - Con correcciones en Pasos 5 y 6*
